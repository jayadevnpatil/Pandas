# %%
import pandas as pd

# %%
df = pd.read_csv("./stack-overflow-developer-survey-2023/survey_results_public.csv")
schema_df = pd.read_csv("./stack-overflow-developer-survey-2023/survey_results_schema.csv")

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.tail(3)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                              Employment  \
# 89181   Prefer not to say                     I prefer not to say
# 89182  Under 18 years old  Employed, part-time;Student, part-time
# 89183     35-44 years old                     Employed, full-time
#
#                                  RemoteWork  \
# 89181                                   NaN
# 89182  Hybrid (some remote, some in-person)
# 89183  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 89181                                                NaN
# 89182                      Hobby;School or academic work
# 89183  Hobby;Professional development or self-paced l...
#
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
schema_df.set_index('qid',inplace=True)

# %%
schema_df.head()
# Out:
#            qname                                           question  \
# qid
# QID16         S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12   MetaInfo                                  Browser Meta Info
# QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# QID312      Q120
# QID1          S1  <span style="font-size:22px; font-family: aria...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID310      False    DB       TB
# QID312       True    MC     SAVR
# QID1        False    DB       TB

# %%
schema_df.loc['QID290']
# Out:
#               qname                                           question  \
# qid
# QID290    Frequency  How frequently do you experience each of the f...
# QID290  Frequency_1  Needing help from people outside of your immed...
# QID290  Frequency_2  Interacting with people outside of your immedi...
# QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#        force_resp    type selector
# qid
# QID290      False  Matrix   Likert
# QID290        NaN      MC     MAVR
# QID290        NaN      MC     MAVR
# QID290        NaN      MC     MAVR

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
schema_df.set_index('qname',inplace=True)
schema_df.sort_index(ascending=False)
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TechList              QID322
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# SOAI                  QID325
# S7                    QID131
# S6                    QID295
# S5                    QID313
# S4                     QID91
# S3                     QID61
# S2                    QID190
# S1                      QID1
# S0                     QID16
# RemoteWork            QID308
# Q310                  QID310
# Q120                  QID312
# PurchaseInfluence     QID278
# ProfessionalTech      QID304
# ...

# %%
schema_df.reset_index(inplace=True)

# %%
high_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary, ['Country', 'LanguageHaveWorkedWith', 'ConvertedCompYearly']]
# Out:
#                                                  Country  \
# 1                               United States of America
# 2                               United States of America
# 3                               United States of America
# 5      United Kingdom of Great Britain and Northern I...
# 6                               United States of America
# ...                                                  ...
# 89143                           United States of America
# 89144                                            Austria
# 89154                           United States of America
# 89156                           United States of America
# 89157                                             Canada
#
#                                   LanguageHaveWorkedWith  ConvertedCompYearly
# 1                             HTML/CSS;JavaScript;Python             285000.0
# 2                             Bash/Shell (all shells);Go             250000.0
# ...

# %%
countries = ['United States of America', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 6        United States of America
# 7        United States of America
#                    ...
# 89164                       India
# 89165                       India
# 89167                       India
# 89175    United States of America
# 89178    United States of America
# Name: Country, Length: 35107, dtype: object

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1                               HTML/CSS;JavaScript;Python
# 2                               Bash/Shell (all shells);Go
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                           HTML/CSS;JavaScript;TypeScript
#                                ...
# 89179              HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89183                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: object

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# 1                               HTML/CSS;JavaScript;Python
# 7        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 9           HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 10                       C#;C++;HTML/CSS;JavaScript;Python
# 11       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89172    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89176    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
df.sort_values(by=['Country','ConvertedCompYearly'], ascending=[True,False], inplace=True)

# %%
df['Country'].head()
# Out:
# 88347    Afghanistan
# 86038    Afghanistan
# 1334     Afghanistan
# 57361    Afghanistan
# 17872    Afghanistan
# Name: Country, dtype: object

# %%
df[['Country','ConvertedCompYearly']].head(50)
# Out:
#            Country  ConvertedCompYearly
# 88347  Afghanistan            9203683.0
# 86038  Afghanistan              68000.0
# 1334   Afghanistan               2403.0
# 57361  Afghanistan               2288.0
# 17872  Afghanistan               1144.0
# 36048  Afghanistan                915.0
# 53321  Afghanistan                794.0
# 41678  Afghanistan                648.0
# 39426  Afghanistan                 48.0
# 37955  Afghanistan                 41.0
# 2641   Afghanistan                 33.0
# 2300   Afghanistan                  NaN
# 3910   Afghanistan                  NaN
# 4221   Afghanistan                  NaN
# 4409   Afghanistan                  NaN
# 10142  Afghanistan                  NaN
# 10376  Afghanistan                  NaN
# 14419  Afghanistan                  NaN
# 15958  Afghanistan                  NaN
# 20377  Afghanistan                  NaN
# 21497  Afghanistan                  NaN
# 21672  Afghanistan                  NaN
# ...

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# 53268    74351432.0
# 77848    73607918.0
# 66223    72714292.0
# 28121    57513831.0
# 19679    36573181.0
# 55102    17612921.0
# 80586    11000000.0
# 83679    10319366.0
# 47797     9915585.0
# 88347     9203683.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10, 'ConvertedCompYearly')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 53268       53269  I agree                     I am a developer by profession
# 77848       77849  I agree                     I am a developer by profession
# 66223       66224  I agree                     I am a developer by profession
# 28121       28122  I agree                     I am a developer by profession
# 19679       19680  I agree                     I am a developer by profession
# 55102       55103  I agree  I am not primarily a developer, but I write co...
# 80586       80587  I agree                     I am a developer by profession
# 83679       83680  I agree                     I am a developer by profession
# 47797       47798  I agree                     I am a developer by profession
# 88347       88348  I agree                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
df.nsmallest(10, 'ConvertedCompYearly')
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 47423       47424  I agree  I am a developer by profession  45-54 years old
# 17985       17986  I agree  I am a developer by profession  18-24 years old
# 64955       64956  I agree  I am a developer by profession  45-54 years old
# 2243         2244  I agree  I am a developer by profession  25-34 years old
# 63213       63214  I agree  I am a developer by profession  18-24 years old
# 41416       41417  I agree  I am a developer by profession  25-34 years old
# 85524       85525  I agree  I am a developer by profession  35-44 years old
# 13708       13709  I agree  I am a developer by profession  25-34 years old
# 52429       52430  I agree  I am a developer by profession  35-44 years old
# 87480       87481  I agree  I am a developer by profession  18-24 years old
#
#                                     Employment  \
# 47423                      Employed, full-time
# ...

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryUSDYearly'}, inplace=True)
df.head()
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 88347       88348  I agree  I am a developer by profession  25-34 years old
# 86038       86039  I agree  I am a developer by profession  35-44 years old
# 1334         1335  I agree  I am a developer by profession  18-24 years old
# 57361       57362  I agree  I am a developer by profession  18-24 years old
# 17872       17873  I agree  I am a developer by profession  25-34 years old
#
#                                               Employment  \
# 88347                                Employed, full-time
# 86038  Employed, full-time;Independent contractor, fr...
# 1334                                 Employed, full-time
# 57361                                Employed, full-time
# 17872                                Employed, part-time
#
#                                  RemoteWork  \
# 88347  Hybrid (some remote, some in-person)
# 86038                                Remote
# ...

# %%
df['SalaryUSDYearly'].head()
# Out:
# 88347    9203683.0
# 86038      68000.0
# 1334        2403.0
# 57361       2288.0
# 17872       1144.0
# Name: SalaryUSDYearly, dtype: float64

# %%
df['SOAccount']
# Out:
# 88347     No
# 86038    Yes
# 1334     Yes
# 57361    Yes
# 17872    Yes
#         ...
# 88820    NaN
# 88828    NaN
# 88830    NaN
# 89028    NaN
# 89159    NaN
# Name: SOAccount, Length: 89184, dtype: object

# %%
df['SOAccount'].map({'Yes':True, 'No':False})
# Out:
# 88347    False
# 86038     True
# 1334      True
# 57361     True
# 17872     True
#          ...
# 88820      NaN
# 88828      NaN
# 88830      NaN
# 89028      NaN
# 89159      NaN
# Name: SOAccount, Length: 89184, dtype: object
